# %%
from timeit import default_timer
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
import corner
import copy
import pandas as pd
# %matplotlib inline

import logging

from bilby.core.prior import PriorDict, PowerLaw, Uniform, Sine, Cosine, DeltaFunction
from bilby.gw.conversion import bilby_to_lalsimulation_spins,  generate_component_spins, generate_component_masses
from pycbc.detector import Detector
from sifce import datatools, utils, population


logger=logging.getLogger(__name__)
logging.basicConfig(level=logging.DEBUG)

pd.set_option('display.max_columns', None)

# %%
prior_waves=dict(mass_ratio=PowerLaw(alpha=0, name='mass_ratio', minimum=0.125, maximum=1),
                mass_1= PowerLaw(alpha=-1, name='mass_1', minimum=10, maximum=80),
                a_1 = Uniform(name='a_1', minimum=0, maximum=0.99),
                a_2 = Uniform(name='a_2', minimum=0, maximum=0.99),
                tilt_1 = Sine(name='tilt_1'),
                tilt_2 = Sine(name='tilt_2'),
                phi_12 = Uniform(name='phi_12', minimum=0, maximum=2 * np.pi, boundary='periodic'),
                phi_jl = Uniform(name='phi_jl', minimum=0, maximum=2 * np.pi, boundary='periodic'),
                luminosity_distance = PowerLaw(alpha=2, name='luminosity_distance', minimum=50, maximum=2000, unit='Mpc', latex_label='$d_L$'),
                dec =  Cosine(name='dec'),
                ra =  Uniform(name='ra', minimum=0, maximum=2 * np.pi, boundary='periodic'),
                theta_jn =  Sine(name='theta_jn'),
                psi =  Uniform(name='psi', minimum=0, maximum=np.pi, boundary='periodic'),
                phase =  Uniform(name='phase', minimum=0, maximum=2 * np.pi, boundary='periodic'),
                reference_frequency = DeltaFunction(20),
                )
PDict = PriorDict(dictionary=prior_waves)
samples = PDict.sample(20)
samples = generate_component_masses(samples)
samples = generate_component_spins(samples)

# %%
samples_df = pd.DataFrame(samples)

waveform_generation_labels = [
    "mass_1",
    "mass_2",
    "spin_1x",
    "spin_1y",
    "spin_1z",
    "spin_2x",
    "spin_2y",
    "spin_2z",
    "theta_jn",
    "phase",
]
detector_position_labels = [
    "ra",
    "dec",
    "psi",
]


delta_f = 1 / 8.0
f_start = 20
f_max = 512
approximant = "IMRPhenomXPHM"
end_time = 10000000


detectors = dict()
psds = dict()
for ifo in ['H1', 'L1', 'V1']:
    psds[ifo] = utils.read_psd_from_txt(
        f"o3_{ifo.lower()}.txt",
        f_min=f_start,
        f_max=f_max,
        delta_f=delta_f,
        basedir="/home/rudall/Projects/SIFCE",
        asd=True,
    )
    detectors[ifo] = Detector(ifo)

snr_sky = []
snr_standard = []
    
samples_df.drop(columns=detector_position_labels) 
    
start = default_timer()
    
for idx, row in samples_df.iterrows():
    wf_params = row[waveform_generation_labels].to_dict()
    hp, hc = datatools.compute_hphc_fd(wf_params, approximant, delta_f=delta_f, f_start=f_start, f_max=f_max)
    
    sky_positions = PDict.sample_subset(keys=detector_position_labels,size=1)
    scattered_snr_opt, _ = datatools.sky_scatter_snr(
        sky_positions,
        dict(
            plus_template = hp,
            cross_template = hc,
            ),
        end_time=end_time,
        psd_dict=psds,
        detector_obj_dict=detectors,
        fmin=f_start,
        fmax=f_max
    )
    for key in psds.keys():
        scattered_snr_opt[key+"_sky"] = scattered_snr_opt.pop(key)[0]
    scattered_snr_opt['net_sky'] = scattered_snr_opt.pop('net')[0]
    snr_sky += [scattered_snr_opt]
    
    strains_dict = dict()
    for ifo in detectors.keys():
        strain = datatools.project_and_combine(
            sky_positions,
            dict(
                plus=hp,
                cross=hc,
            ),
            end_time,
            detector_obj=detectors[ifo],
            
        )
        strains_dict[ifo] = dict(template=strain)
        
    snr_opt, _ = datatools.compute_snr_fd(
        strains_dict,
        psds,
        fmin=f_start,
        fmax=f_max
    )
    snr_standard += [snr_opt]
    
end = default_timer()
print(end-start)

sky_snrs_df = pd.DataFrame(snr_sky)
standard_snrs_df = pd.DataFrame(snr_standard)

samples_df = samples_df.join(sky_snrs_df)
samples_df = samples_df.join(standard_snrs_df)

print(samples_df.keys())
# Out:
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.87610415],[-0.21574117]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.71100049],[0.37186558]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.2574163],[-0.15711827]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.87610415], [-0.21574117]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.71100049], [0.37186558]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.2574163], [-0.15711827]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.6175441],[-0.19931131]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.42505084],[0.34492773]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.70897717],[-0.47989582]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.6175441], [-0.19931131]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.42505084], [0.34492773]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.70897717], [-0.47989582]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.1629388],[-0.53896543]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.00403525],[0.74252885]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.34546704],[-0.04486344]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.1629388], [-0.53896543]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.00403525], [0.74252885]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.34546704], [-0.04486344]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.62328673],[0.65280456]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.36476749],[-0.53663275]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.19363113],[0.12697455]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.62328673], [0.65280456]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.36476749], [-0.53663275]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.19363113], [0.12697455]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.02637539],[-0.82074334]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.18123271],[0.64227924]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.28233564],[0.55551443]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.02637539], [-0.82074334]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.18123271], [0.64227924]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.28233564], [0.55551443]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.06462782],[-0.98499498]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.01517717],[0.82256391]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.17745668],[0.15384828]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.06462782], [-0.98499498]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.01517717], [0.82256391]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.17745668], [0.15384828]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.32772291],[-0.39889449]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.54042448],[0.35215358]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.29356979],[-0.32773411]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.32772291], [-0.39889449]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.54042448], [0.35215358]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.29356979], [-0.32773411]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.26509096],[-0.06634538]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.65510284],[-0.05130455]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.48540352],[0.1741315]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.26509096], [-0.06634538]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.65510284], [-0.05130455]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.48540352], [0.1741315]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.30090761],[-0.04920846]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.12231383],[0.19835598]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.36418482],[-0.91577566]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.30090761], [-0.04920846]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.12231383], [0.19835598]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.36418482], [-0.91577566]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.6980957],[0.45828665]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.5105539],[-0.58065583]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.60089881],[0.36747137]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.6980957], [0.45828665]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.5105539], [-0.58065583]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.60089881], [0.36747137]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.66653095],[0.39162868]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.35243491],[-0.23080614]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.15314522],[-0.40903067]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.66653095], [0.39162868]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.35243491], [-0.23080614]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.15314522], [-0.40903067]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.27430471],[-0.54617964]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.17441331],[0.79339667]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.38766486],[-0.06516592]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.27430471], [-0.54617964]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.17441331], [0.79339667]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.38766486], [-0.06516592]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.10279627],[-0.26331374]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.32400758],[0.07412163]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.63799111],[-0.07377255]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.10279627], [-0.26331374]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.32400758], [0.07412163]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.63799111], [-0.07377255]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.2723524],[0.37055497]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.12106595],[-0.54761916]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.58890496],[0.61342314]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.2723524], [0.37055497]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.12106595], [-0.54761916]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.58890496], [0.61342314]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.43417181],[0.7262828]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.30906049],[-0.42606349]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.12446438],[-0.32185535]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.43417181], [0.7262828]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.30906049], [-0.42606349]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.12446438], [-0.32185535]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.14476371],[-0.8628593]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.14264722],[0.55583343]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.20108256],[0.22338185]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.14476371], [-0.8628593]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.14264722], [0.55583343]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.20108256], [0.22338185]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.67763709],[0.44072854]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.67876683],[-0.64700115]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.21144832],[0.61160177]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.67763709], [0.44072854]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.67876683], [-0.64700115]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.21144832], [0.61160177]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.47568354],[-0.52357615]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.11170117],[0.56306186]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.19983563],[-0.58000803]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.47568354], [-0.52357615]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.11170117], [0.56306186]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.19983563], [-0.58000803]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.12329608],[0.1952938]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.51867088],[-0.18183836]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.23136863],[-0.05733305]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.12329608], [0.1952938]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.51867088], [-0.18183836]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.23136863], [-0.05733305]
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.2267742],[-0.51156384]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [0.09240641],[0.36120083]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:sky_scatter_snr: fp, fc are [-0.05168712],[0.46973414]
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'plus_template')
#                 plus power:2
#                  cross_power:0
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('plus_template', 'cross_template')
#                 plus power:1
#                  cross_power:1
#
# DEBUG:sifce.datatools:sky_scatter_snr:inner product key ('cross_template', 'cross_template')
#                 plus power:0
#                  cross_power:2
#
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.2267742], [-0.51156384]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [0.09240641], [0.36120083]
# DEBUG:sifce.datatools:project_and_combine: fp, fc are [-0.05168712], [0.46973414]
# 1.0812702940002055
# Index(['mass_ratio', 'mass_1', 'a_1', 'a_2', 'tilt_1', 'tilt_2', 'phi_12',
#        'phi_jl', 'luminosity_distance', 'dec', 'ra', 'theta_jn', 'psi',
#        'phase', 'reference_frequency', 'mass_2', 'iota', 'spin_1x', 'spin_1y',
#        'spin_1z', 'spin_2x', 'spin_2y', 'spin_2z', 'phi_1', 'phi_2', 'H1_sky',
#        'L1_sky', 'V1_sky', 'net_sky', 'H1', 'L1', 'V1', 'net'],
#       dtype='object')

# %%
samples_df
# Out:
#     mass_ratio     mass_1       a_1       a_2    tilt_1    tilt_2    phi_12  \
# 0     0.161872  32.337039  0.461524  0.073747  1.389259  2.409976  4.459776
# 1     0.594491  34.640767  0.807067  0.258517  1.092325  0.643425  3.046044
# 2     0.465032  44.676593  0.066259  0.957998  2.022930  1.753207  0.043599
# 3     0.980489  46.984608  0.437650  0.722613  2.523513  1.744187  5.843757
# 4     0.658860  10.463179  0.293291  0.257412  0.297208  0.819270  4.015823
# 5     0.490510  13.189713  0.925267  0.225545  0.991203  1.925780  5.603173
# 6     0.925446  14.295186  0.624692  0.033070  1.088468  1.361647  1.898038
# 7     0.848129  13.912963  0.765057  0.535359  1.003959  2.639502  3.907939
# 8     0.144675  18.795246  0.597114  0.568104  1.761225  1.994385  5.997127
# 9     0.542861  61.148535  0.697250  0.413344  1.768437  2.963223  4.501405
# 10    0.397947  53.310885  0.452422  0.427549  0.978033  0.431690  1.386907
# 11    0.781048  48.984407  0.447667  0.822645  1.575454  2.402021  3.829750
# 12    0.365195  25.888398  0.367169  0.538428  2.049364  2.677901  4.463926
# 13    0.224675  13.548510  0.839565  0.806831  1.542906  1.671111  0.688016
# 14    0.583072  13.008476  0.621258  0.468097  0.884679  1.356423  4.055683
# 15    0.600540  32.412951  0.435019  0.167132  2.251652  1.451453  5.221651
# 16    0.615334  19.631983  0.986139  0.306044  1.076835  1.319336  4.974536
# 17    0.674103  15.053508  0.942864  0.066894  1.381905  1.663792  5.508686
# 18    0.800847  16.254678  0.850048  0.268852  1.815255  1.955559  0.338114
# 19    0.337272  10.542159  0.173361  0.389574  1.353054  1.425323  4.559665
#
#       phi_jl  luminosity_distance       dec        ra  theta_jn       psi  \
# 0   5.300112          1727.098060 -0.529042  5.099198  1.649876  1.641175
# 1   2.221907          1935.847300  0.377911  6.206141  2.140187  1.799896
# 2   0.656763           397.363420  0.254082  3.003381  2.105747  0.209953
# 3   0.144824           525.042880 -0.482647  0.289915  0.679264  1.683685
# 4   4.839709          1900.957270  0.189593  3.376191  1.810027  0.908559
# 5   5.340329          1583.925704 -0.214201  2.652476  0.747178  2.082494
# 6   4.703095          1736.097896 -0.613954  6.134864  2.549962  2.654061
# 7   4.110611          1877.140776  0.713347  6.237430  0.774146  0.504341
# 8   3.971442          1746.916887 -0.344919  0.048647  0.452846  2.771943
# 9   2.129410          1983.243993  0.557403  3.756189  1.238503  0.760937
# 10  2.226347           488.515587  0.826152  3.564559  2.159691  0.163079
# 11  5.850342          1298.283052 -0.512569  1.412488  1.927260  0.786536
# 12  3.102654          1975.952481 -0.355453  5.698920  0.961385  2.738850
# 13  0.675239          1809.631296 -0.853049  1.955483  1.335520  2.888316
# 14  3.283642          1880.783323  1.277064  6.241433  1.785943  1.662183
# 15  0.641956           256.637881  0.715306  4.719249  2.589518  2.425280
# 16  3.712791          1136.331492  1.409507  0.573529  2.692950  0.109936
# 17  1.582788           450.066000 -1.098631  5.438949  1.642041  2.615033
# 18  2.155246          1501.205246 -0.313894  2.548136  1.499078  2.430203
# 19  5.124908          1306.140800  0.873233  0.442771  1.152006  2.606310
#
#        phase  reference_frequency     mass_2      iota   spin_1x   spin_1y  \
# 0   4.167378                 20.0   5.234461  2.048299 -0.156206 -0.426217
# 1   3.629664                 20.0  20.593612  1.962196 -0.063708  0.713595
# 2   1.313784                 20.0  20.776061  2.015278 -0.048094  0.035203
# 3   0.528277                 20.0  46.067904  0.687810 -0.232519  0.101246
# 4   4.875764                 20.0   6.893765  1.826423 -0.043186 -0.074244
# 5   3.290940                 20.0   6.469685  0.950712  0.303386 -0.712234
# 6   0.359416                 20.0  13.229426  2.656064  0.224991  0.505627
# 7   1.944737                 20.0  11.799988  0.870578  0.505111 -0.401758
# 8   4.202297                 20.0   2.719207  1.081021 -0.577471 -0.101485
# 9   3.855484                 20.0  33.195127  0.936473  0.007840  0.683632
# 10  1.021149                 20.0  21.214929  1.997364 -0.181114 -0.328637
# 11  2.119288                 20.0  38.259181  1.971167  0.038190  0.446030
# 12  5.101583                 20.0   9.454313  0.968071  0.060869  0.320185
# 13  4.611275                 20.0   3.044009  1.022233  0.435752 -0.717246
# 14  1.996848                 20.0   7.584875  1.799938  0.000409 -0.480674
# 15  4.286831                 20.0  19.465275  2.484849  0.331825 -0.064441
# 16  1.820494                 20.0  12.080219  2.768020 -0.097051 -0.862817
# 17  3.696517                 20.0  10.147621  1.396299  0.460518  0.803476
# 18  0.526298                 20.0  13.017510  1.292078  0.023797 -0.824431
# 19  0.954583                 20.0   3.555572  1.222379  0.049022  0.162014
#
#      spin_1z   spin_2x   spin_2y   spin_2z     phi_1     phi_2        H1_sky  \
# 0   0.083324 -0.040554  0.027977 -0.054875  4.361097  2.537688   3967.990786
# 1   0.371592 -0.001009 -0.155091  0.206825  1.659837  4.705882  10161.535571
# 2  -0.028948 -0.783748  0.522780 -0.173782  2.509742  2.553342   7043.983465
# 3  -0.356681 -0.469707  0.534793 -0.124667  2.730919  2.291491  18232.694249
# 4   0.280433 -0.064030  0.176843  0.175749  4.185547  1.918186   1433.665943
# 5   0.506753 -0.057901 -0.203402 -0.078394  5.115076  4.435064   6844.352411
# 6   0.289759 -0.032214  0.002953  0.006866  1.152130  3.050168   4558.984762
# 7   0.410810 -0.256499 -0.024292 -0.469284  5.611264  3.236018   2146.954438
# 8  -0.113022 -0.514644  0.057932 -0.233510  3.315556  3.029498   1108.789554
# 9  -0.136910  0.071531 -0.016180 -0.406786  1.559328  6.060733  11287.576147
# 10  0.252748  0.138242 -0.113536  0.388325  4.208695  5.595602  10308.432190
# 11 -0.002085  0.314314 -0.456738 -0.607735  1.485383  5.315133   8111.166388
# 12 -0.169084  0.218252 -0.101771 -0.481574  1.382934  5.846860   1444.705871
# 13  0.023413  0.757662 -0.265321 -0.080801  5.258331  5.946347   1481.353152
# 14  0.393591 -0.362488  0.278929  0.099580  4.713239  2.485737   2921.049615
# 15 -0.273826  0.051798 -0.157652  0.019899  6.091371  5.029837  12491.665134
# 16  0.467546 -0.293085 -0.044336  0.076149  4.600379  3.291729   8398.880046
# 17  0.177042  0.064086  0.018141 -0.006212  1.050348  0.275849   3128.086154
# 18 -0.205738  0.089409 -0.232604 -0.100911  4.741246  5.079360    965.598020
# 19  0.037451  0.347663 -0.166461  0.056473  1.276975  5.836641   1627.597341
#
#           L1_sky       V1_sky       net_sky            H1            L1  \
# 0    4651.631553   674.805835   6151.259213   3967.990814   4651.631513
# 1   10574.021309  6019.736065  15852.569322  10161.535581  10574.021293
# 2   11336.242153  2111.509513  13512.459496   7043.983503  11336.242120
# 3   17073.415785  2282.442306  25082.707370  18232.694231  17073.415801
# 4    1701.497401   707.221899   2334.663628   1433.666229   1701.497213
# 5    7295.056945   777.197765  10033.297171   6844.352483   7295.056889
# 6    7342.433068  1820.902273   8832.403439   4558.984806   7342.433044
# 7    6755.425798  2002.314440   7365.762295   2146.954453   6755.425802
# 8    1119.830327  1703.623389   2320.725509   1108.789576   1119.830239
# 9   13060.836584  3481.127308  17610.027680  11287.576127  13060.836606
# 10   7344.309054  2738.021192  12949.880684  10308.432171   7344.309069
# 11  12596.886374  2442.351871  15180.172896   8111.166421  12596.886343
# 12   2622.537311  1821.840794   3504.851049   1444.705962   2622.537297
# 13   2101.106432  1204.599494   2839.034227   1481.353027   2101.106562
# 14   2473.152916   392.414623   3847.467406   2921.049491   2473.153002
# 15  10544.812050  2036.156132  16473.636235  12491.665169  10544.812024
# 16  12583.890888  3290.410076  15482.967880   8398.880020  12583.890914
# 17   3000.222248  1248.520135   4510.549750   3128.086238   3000.222154
# 18   3543.953550   616.885770   3724.585125    965.597919   3543.953576
# 19   1321.943317   627.896300   2188.803555   1627.597498   1321.943180
#
#              V1           net
# 0    674.805951   6151.259213
# 1   6019.736105  15852.569332
# 2   2111.509524  13512.459490
# 3   2282.442278  25082.707366
# 4    707.221507   2334.663547
# 5    777.197666  10033.297172
# 6   1820.902363   8832.403460
# 7   2002.314396   7365.762291
# 8   1703.623658   2320.725674
# 9   3481.127256  17610.027673
# 10  2738.021266  12949.880694
# 11  2442.351885  15180.172890
# 12  1821.840814   3504.851087
# 13  1204.599240   2839.034150
# 14   392.415033   3847.467408
# 15  2036.156077  16473.636237
# 16  3290.409983  15482.967867
# 17  1248.520367   4510.549810
# 18   616.885816   3724.585131
# 19   627.895926   2188.803482
